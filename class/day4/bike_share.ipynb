# %%
import pandas as pd
import seaborn as sns
from __future__ import division

# %%
cd /Users/Ikkei/data-analysis/DAT18NYC/data
# Out:
# /Users/Ikkei/data-analysis/DAT18NYC/data

# %%
ls
# Out:
# Batting.csv*   bikeshare.csv  bikeshare.txt  lahman.sqlite  msleep.csv     tweets.csv

# %%
df = pd.read_csv('bikeshare.csv')
df.convert_objects(convert_numeric=True)
df = df.replace({'yr': {0: 2011, 1:2012}})

# %%
df.head()
# Out:
#    instant      dteday  season    yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1  2011     1   0        0        6           0
# 1        2  2011-01-01       1  2011     1   1        0        6           0
# 2        3  2011-01-01       1  2011     1   2        0        6           0
# 3        4  2011-01-01       1  2011     1   3        0        6           0
# 4        5  2011-01-01       1  2011     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81          0       3          13   16
# 1           1  0.22  0.2727  0.80          0       8          32   40
# 2           1  0.22  0.2727  0.80          0       5          27   32
# 3           1  0.24  0.2879  0.75          0       3          10   13
# 4           1  0.24  0.2879  0.75          0       0           1    1

# %%
sns.set_style('white')
pd.scatter_matrix(df[['temp','atemp','hum','windspeed']], figsize=[10,10], alpha=0.2, diagonal='kde') #karnel density estimation
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640   2011.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000   2011.000000      1.000000      0.000000
# 25%     4345.5000      2.000000   2011.000000      4.000000      6.000000
# 50%     8690.0000      3.000000   2012.000000      7.000000     12.000000
# 75%    13034.5000      3.000000   2012.000000     10.000000     18.000000
# max    17379.0000      4.000000   2012.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

df['windspeed'].plot(ax=axes[0], kind='hist')
df['windspeed'].plot(ax=axes[1], kind='kde')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

df['hum'].plot(ax=axes[0], kind='hist')
df['hum'].plot(ax=axes[1], kind='kde')

# %%
sns.lmplot(x='atemp', y='hum', data=df)

# %% [markdown]
# plt.figure()
# plt.subplot(1,1,1)
# plt.plot(x,y)
# plt.show()
