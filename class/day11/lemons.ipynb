# %%
import pandas as pd
from sklearn import tree
from sklearn.cross_validation import cross_val_score

# Load in data and create sets. dropping all na columns on the live data set.
lemons = pd.read_csv('/Users/Ikkei/data-analysis/DAT18NYC/data/lemons.csv')
lemons_oos = pd.read_csv('/Users/Ikkei/data-analysis/DAT18NYC/data/lemons_oos.csv')

# %%
lemons.count()
# Out:
# RefId                                51088
# IsBadBuy                             51088
# PurchDate                            51088
# Auction                              51088
# VehYear                              51088
# VehicleAge                           51088
# Make                                 51088
# Model                                51088
# Trim                                 49426
# SubModel                             51082
# Color                                51082
# Transmission                         51081
# WheelTypeID                          48819
# WheelType                            48816
# VehOdo                               51088
# Nationality                          51086
# Size                                 51086
# TopThreeAmericanName                 51086
# MMRAcquisitionAuctionAveragePrice    51076
# MMRAcquisitionAuctionCleanPrice      51076
# MMRAcquisitionRetailAveragePrice     51076
# MMRAcquisitonRetailCleanPrice        51076
# ...

# %%
lemons_oos.head()
# Out:
#    RefId  PurchDate Auction  VehYear  VehicleAge   Make         Model Trim  \
# 0      3  12/7/2009   ADESA     2005           4  DODGE    STRATUS V6  SXT
# 1      4  12/7/2009   ADESA     2004           5  DODGE          NEON  SXT
# 2      8  12/7/2009   ADESA     2005           4   FORD        TAURUS   SE
# 3      9  12/7/2009   ADESA     2007           2    KIA       SPECTRA   EX
# 4     10  12/7/2009   ADESA     2007           2   FORD  FIVE HUNDRED  SEL
#
#            SubModel   Color      ...      MMRCurrentRetailAveragePrice  \
# 0  4D SEDAN SXT FFV  MAROON      ...                              7146
# 1          4D SEDAN  SILVER      ...                              4375
# 2       4D SEDAN SE   WHITE      ...                              6942
# 3       4D SEDAN EX   BLACK      ...                              9637
# 4      4D SEDAN SEL     RED      ...                             12580
#
#    MMRCurrentRetailCleanPrice PRIMEUNIT  AUCGUART  BYRNO VNZIP1 VNST  \
# ...

# %%
corre
